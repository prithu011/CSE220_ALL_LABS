# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **Assignment Part 1: Doubly Linked List**

# %% [markdown]
# For Assignment Part 1, you should write your full code in the following cells along with your driver codes on your own.

# %%
#Assignment Part 1
class Patient:
  def __init__(self,id, name, age,blood_group):
    self.next = None
    self.prev = None
    self.id=id
    self.name=name
    self.age=age
    self.blood_group=blood_group

# %%
class WRM(Patient):
  patientQueue = Patient(None,None,None,None)
  patientQueue.next = patientQueue
  patientQueue.prev = patientQueue
  tail = patientQueue

  def __init__(self):
    pass

  @classmethod
  def RegisterPatient(cls,id, name, age, bloodgroup):
    newPatient = Patient(id, name, age, bloodgroup)
    newPatient.prev = cls.tail
    newPatient.next = cls.patientQueue
    cls.tail.next = newPatient
    cls.tail = cls.tail.next
    cls.patientQueue.prev = newPatient
    print("Patient is registered successfully")
    return newPatient
  @classmethod
  def ServePatient(cls):
    if cls.patientQueue.next != cls.patientQueue:
      servingPatient = cls.patientQueue.next
      temp = servingPatient.next
      cls.patientQueue.next = temp
      temp.prev = cls.patientQueue
      print(f"{servingPatient.name} is being served")
    else:
      print("No Patient is served")
  @classmethod
  def CancelAll(cls):
    if cls.patientQueue.next != cls.patientQueue:
      cls.patientQueue.next = cls.patientQueue
      cls.patientQueue.prev = cls.patientQueue
      print("Sucessfully cancelled all appointments.")
    else:
      print("No appointments to cancel")
  @classmethod
  def CanDoctorGoHome(cls):
    if cls.patientQueue.next == cls.patientQueue:
      return True
    else:
      return False
  @classmethod
  def ShowAllPatient(cls):
    temp = cls.patientQueue.next
    if cls.patientQueue.next != cls.patientQueue:
      print("Patients in the queue:")
      while temp != cls.patientQueue:
        print(f"{temp.id}:{temp.name}")
        temp = temp.next
    else:
      print("No patient in the queue")
  @classmethod
  def ReverseTheLine(cls):
    if cls.patientQueue.next==cls.patientQueue and cls.patientQueue.prev==cls.patientQueue:
      print("not")
    else:
      temp = cls.patientQueue
      current = cls.patientQueue.next
      temp.next = None
      temp.prev = current
      new = current
      while current != None:
          current.prev = current.next
          current.next = temp
          temp = current
          current= current.prev
      temp.prev = new
      cls.patientQueue = temp
      cls.tail=cls.patientQueue.prev
      print("Succcessfully reverse the line")

# %%
#Write a Tester Code in this cell
print("**Welcome to Waiting Room Management System**")
x = True
while x == True:
  print("-"*30)
  print("Choose an action from below")
  print("-"*30)
  print("1.Add new patient")
  print("2.Serve a patient")
  print("3.Show all patients")
  print("4.Can doctor go home?")
  print("5.Cancel all appointment")
  print("6.Reverse the line")
  print("7.Exit")
  print("-"*30)
  print("-"*30)
  action = int(input("Enter a number from the menu:"))

  if action == 1:
    id = int(input("Enter patient's id:"))
    name = input("Enter patient's name:")
    age = input("Enter patient's age:")
    bg = input("Enter patient's blood group:")
    WRM.RegisterPatient(id,name,age,bg)
  if action == 2:
    WRM.ServePatient()
  if action == 3:
    WRM.ShowAllPatient()
  if action == 4:
    if WRM.CanDoctorGoHome() == True:
      print("Yes. Doctor can go home")
    else:
      print("No. Doctor can't go home")
  if action == 5:
    WRM.CancelAll()
  if action == 6:
    WRM.ReverseTheLine()
  if action == 7:
    x = False
# Out:
# **Welcome to Waiting Room Management System**
# ------------------------------
# Choose an action from below
# ------------------------------
# 1.Add new patient
# 2.Serve a patient
# 3.Show all patients
# 4.Can doctor go home?
# 5.Cancel all appointment
# 6.Reverse the line
# 7.Exit
# ------------------------------
# ------------------------------
# Enter a number from the menu:1
# Enter patient's id:1
# Enter patient's name:prithu
# Enter patient's age:21
# Enter patient's blood group:o+
# Patient is registered successfully
# ------------------------------
# Choose an action from below
# ------------------------------
# 1.Add new patient
# 2.Serve a patient
# 3.Show all patients
# 4.Can doctor go home?
# 5.Cancel all appointment
# 6.Reverse the line
# 7.Exit
# ------------------------------
# ------------------------------
# Enter a number from the menu:2
# No Patient is served
# ------------------------------
# Choose an action from below
# ------------------------------
# ...

# %% [markdown]
# **Assignment Part 2: Stack**
#
# Linked List based Stack is implemented in the following cell.

# %%
class Node:
  def __init__(self,elem=None,next=None):
    self.elem = elem
    self.next = next

class Stack:
  def __init__(self):
    self.__top = None

  def push(self,elem):
    nn = Node(elem,self.__top)
    self.__top = nn

  def pop(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    e = self.__top
    self.__top = self.__top.next
    return e.elem

  def peek(self):
    if self.__top == None:
      #print('Stack Underflow')
      return None
    return self.__top.elem

  def isEmpty(self):
    return self.__top == None

# %%
#You can run this driver code cell to understand the methods of Stack class
st = Stack()
st.push(4)
st.push(3)
st.push(5)
st.push(1)
st.push(9)

print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print('Popped Element: ',st.pop())
print('Peeked Element: ',st.peek())
print('Popped Element: ',st.pop())
print(st.isEmpty())
# Out:
# Peeked Element:  9
# Popped Element:  9
# Popped Element:  1
# Popped Element:  5
# Peeked Element:  3
# Popped Element:  3
# Popped Element:  4
# Peeked Element:  None
# Popped Element:  None
# True

# %% [markdown]
# You can print your stack using this code segment

# %%
def print_stack(st):
  if st.isEmpty():
    return
  p = st.pop()
  print('|',p,end=' ')
  if p<10:
    print(' |')
  else:
    print('|')
  #print('------')
  print_stack(st)
  st.push(p)

# st = Stack()
# st.push(4)
# st.push(3)
# st.push(5)
# st.push(1)
# st.push(9)
# print_stack(st)
# print('------')

# %% [markdown]
# Task 1: Diamond Count

# %%
def diamond_count(stack,string):
    d_count=0
    for i in string:
        if i=='<':
           stack.push(i)
        elif i=='>':
             if not stack.isEmpty() and stack.peek()=='<':
                d_count+=1
                stack.pop()
    return d_count




print('Test 01')
stack = Stack()
string = '<..><.<..>> '
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')


print('Test 02')
stack = Stack()
string = '<<<..<......<<<<....>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 1
unittest.output_test(returned_value, 1)
print('-----------------------------------------')


print('Test 03')
stack = Stack()
string = '>>><...<<..>>...>...>>>'
returned_value = diamond_count(stack,string)
print(f'Number of Diamonds: {returned_value}') #This should print 3
unittest.output_test(returned_value, 3)
print('-----------------------------------------')
# Out:
# Test 01
# Number of Diamonds: 3
# Accepted
# -----------------------------------------
# Test 02
# Number of Diamonds: 1
# Accepted
# -----------------------------------------
# Test 03
# Number of Diamonds: 3
# Accepted
# -----------------------------------------

# %% [markdown]
# Task 2: Tower of Blocks

# %%
def remove_block(stack, n):
    new_stack=Stack()
    count=0
    while not stack.isEmpty():
          new_stack.push(stack.pop())
          count+=1
          if count==n:
             new_stack.pop()
             break
    while not new_stack.isEmpty():
          stack.push(new_stack.pop())





print('Test 01')
st = Stack()
st.push(4)
st.push(19)
st.push(23)
st.push(17)
st.push(5)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,2)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()

print('Test 02')
st = Stack()
st.push(73)
st.push(85)
st.push(15)
st.push(41)
print('Stack:')
print_stack(st)
print('------')
remove_block(st,3)
print('After Removal')
print_stack(st)
print('------')

print()
print('======================================')
print()
# Out:
# Test 01
# Stack:
# | 5  |
# | 17 |
# | 23 |
# | 19 |
# | 4  |
# ------
# After Removal
# | 5  |
# | 23 |
# | 19 |
# | 4  |
# ------
#
# ...
#
# Test 02
# Stack:
# | 41 |
# | 15 |
# | 85 |
# | 73 |
# ------
# After Removal
# | 41 |
# | 15 |
# | 73 |
# ------
#
# ...

# %% [markdown]
# Task 3: Stack Reverse

# %%
def conditional_reverse(stack):
    if stack.isEmpty():
       return Stack()
    temp_stack=Stack()
    reversed_stack=Stack()
    temp=None
    while not stack.isEmpty():
          value=stack.pop()
          if value!=temp:
              temp_stack.push(value)
              temp=value
          else:
              temp=None
    while not temp_stack.isEmpty():
          reversed_stack.push(temp_stack.pop())

    return reversed_stack



print('Test 01')
st=Stack()
st.push(10)
st.push(10)
st.push(20)
st.push(20)
st.push(30)
st.push(10)
st.push(50)
print('Stack:')
print_stack(st)
print('------')
reversed_stack=conditional_reverse(st)
print('Conditional Reversed Stack:')
print_stack(reversed_stack) # This stack contains 50, 10, 30, 20, 10 in this order whereas top element should be 10
print('------')
# Out:
# Test 01
# Stack:
# | 50 |
# | 10 |
# | 30 |
# | 20 |
# | 20 |
# | 10 |
# | 10 |
# ------
# Conditional Reversed Stack:
# | 50 |
# | 10 |
# | 30 |
# | 20 |
# | 10 |
# ------
